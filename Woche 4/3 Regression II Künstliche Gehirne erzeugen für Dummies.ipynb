# %% [markdown]
# # Regression II: Künstliche Gehirne erzeugen für Dummies

# %% [markdown]
# ## Neuronale Netze mit Deep Learning Bibliotheken
# In diesem Notebook wollen wir herausfinden, wie wir neuronale Netze mithilfe von Deep Learning Bibliotheken trainieren können. Konkret werden wir dazu die drei Open Source Bibliotheken Keras, Tensorflow und Pytorch verwenden. Opensource ML-Bibliotheken und Frameworks erleichtern die Implementierung und das Training von (tiefen) neuronalen Netzen enorm. In diesem Notebook wollen wir Ihnen einen generellen Überblick über die Funktionsweise dieser drei Bibliotheken/Frameworks geben. Für die nächsten Notebooks von besonderer Relevanz ist die Keras Library, da wir diese noch häufiger verwenden werden. Wenn Sie sich für die Funktionsweise der beiden anderen Bibliotheken interessieren, können Sie sich zusätzlich die beiden darauf folgenden Code-Beispiele ansehen.

# %% [markdown]
# ### Datensatz für die Beispiele
# Der Einfachheit halber werden wir für das Training aller drei Beispiel ML-Modelle den gleichen Datensatz verwenden, den wir im Folgenden in Form zweier Numpy Arrays definieren. Wie Sie vielleicht bereits bemerkt haben, handelt es sich dabei um das Ausgangsverhalten eines [XOR-Gates](https://de.wikipedia.org/wiki/Exklusiv-Oder-Gatter) (zu Deutsch: Exklusives-Oder-Gatter), das wir im Folgenden mit unseren Modellen erlenen möchten.
#
# <img src="./images/xor_gate_aufbau.svg"
#      style="width:400px;"
#     />
# <p style="text-align: center;">
#     Von 30px MovGP0 - selbst erstellt mit Inkscape, CC BY-SA 2.0 de, https://commons.wikimedia.org/w/index.php?curid=22912763
# </p>

# %%
import numpy as np

# %%
x_train = np.array([[0, 0],
                    [0, 1],
                    [1, 0],
                    [1, 1]], dtype = 'float64')

y_train = np.array([[0],
                    [1],
                    [1],
                    [0]], dtype = 'float64')
print(x_train)
print(type(x_train))
print(y_train)
# Out:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# <class 'numpy.ndarray'>
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %% [markdown]
# ### Keras Beispiel

# %% [markdown]
# #### Über Keras
#
# Keras ist eine Python Open-Source-Bibliothek für neuronale Netze. Sie fungiert als Schnittstelle für die TensorFlow-Bibliothek. Aufgrund ihres benutzerfreundlichen und modularen Aufbaus eignet sich Keras unter anderem besonders gut für das schnelle Experimentieren mit tiefen neuronalen Netzen. Mit nur wenigen Zeilen Code lassen sich die Schichten des neuronalen Netzes definieren, zu optimierende Verlustmetrik sowie Optimierungsverfahren festlegen und das Training starten.
#
# <figure>
# <img  src="./images/keras.png" width="100" align="center"/>
# </figure>
#
# #### Funktionsweise
# Der einfachste Weg, ein neuronales Netz in Keras zu definieren ist über die Sequential API. Dabei wird im ersten Schritt ein Sequential Modell definiert, das als eine Art Basis funktioniert. Diesem Sequential Modell können wir dann Schritt für Schritt Ebenen mit `add()` hinzufügen. In unserem Beispiel erstellen wir ein neuronales Netz bestehend aus einem Denselayer (in Keras bezeichnet Denselayer einen "fully connected Layer") mit 3 Neuronen, gefolgt von einer ReLU Aktivierungsschicht und einem weiteren Ausgangs-Denselayer mit der Sigmoid Aktivierungsfunktion. Die Sigmoid Funktion im Ausgang liefert uns einen Wertebereich zwischen null und eins.
#
# Es sei angemerkt, dass das Modell wissen muss, welche Form der Eingabe (wie viele Dimensionen der Eingang hat) es erwarten soll. Aus diesem Grund muss die erste Schicht in einem Sequential Modell (und nur die erste, denn die folgenden Schichten können automatisch auf die Form schließen) Informationen über die Eingabeform erhalten. Dies erfolgt beispielsweise über das Festlegen des `input_dim` Arguments der ersten Schicht. Dies wird im Folgenden Beispiel umgesetzt.
#
# Ist das Keras-Modell fertig definiert, muss es vor dem Start des Trainings noch mit der `compile()`-Methode kompiliert werden. Dazu sollten wir die zu verwendene Verlustmetrik mit `loss` sowie den Optimizer mit `optimizer` festlegen. Keras unterstützt eine Vielzahl an Optimizern, die je nach Art verschiedene Einstellungsmöglichkeiten aufweisen.
# Anschließend lässt sich das Training mit der `fit()`-Methode starten.

# %%
# Load Library and modules
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message="Protobuf gencode version")
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers,Input

# Init the model
model = Sequential()
model.add(Input(shape=(2,)))
model.add(Dense(3))
model.add(Activation('relu'))
model.add(Dense(1, activation='sigmoid'))

# Show optimizer
rmsprop = optimizers.RMSprop(learning_rate=0.01, rho=0.9)

# Compile
model.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])
# Train
model.fit(x_train, y_train, batch_size = 4,
          epochs=200)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.7500 - loss: 0.6737
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.6547
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7500 - loss: 0.6438
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7500 - loss: 0.6382
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.6353
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.6293
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7500 - loss: 0.6286
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.6228
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.6213
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.6170
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7500 - loss: 0.6138
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7500 - loss: 0.6110
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7500 - loss: 0.6065
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7500 - loss: 0.6049
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.5998
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5985
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5940
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5912
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5897
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5859
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5820
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5806
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.5750
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5736
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5699
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5682
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5628
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.5602
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.5574
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5548
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5519
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5468
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.5463
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5406
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.5389
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.5351
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5306
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5293
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5237
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.5223
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5180
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5138
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.5121
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5065
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.5051
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5007
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4964
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4947
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4890
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4875
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4831
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4788
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4771
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4714
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4699
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.4656
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4610
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.4594
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.4537
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4519
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.4477
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.4431
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.4415
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4359
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4339
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4298
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4250
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4236
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4180
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.4158
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4119
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.4069
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4057
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4002
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3977
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3941
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3892
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3873
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3852
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3796
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.3779
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.3735
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.3690
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3667
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3659
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3613
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3560
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3529
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3513
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3480
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3463
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3409
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3400
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3360
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3318
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3291
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3273
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3232
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3206
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3181
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3133
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3125
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.3087
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.3044
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.3039
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2989
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2971
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2943
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2896
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2895
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.2852
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2816
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2805
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2766
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2735
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2721
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.2671
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.2657
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2641
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.2586
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2594
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.2547
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.2517
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.2489
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2474
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2434
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.2432
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2387
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2369
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.2349
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.2312
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2295
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2272
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2237
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2221
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2203
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.2158
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2157
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2120
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2089
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.2086
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2058
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2022
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2015
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1986
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1961
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1939
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.1931
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1885
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1875
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1857
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1832
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1814
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1796
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1772
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1743
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1745
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1702
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1693
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1679
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1650
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1630
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1602
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1595
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1576
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.1545
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1548
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1523
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1506
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.1479
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.1472
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1451
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1426
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1426
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1391
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1375
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1370
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1355
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1340
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1309
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1311
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1286
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1269
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1261
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1242
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1222
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1213
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1202
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1191
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1172
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1146
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1141
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1128
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1109
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1105
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1092
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1068
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1056
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1051
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1040

# %% [markdown]
# ### (Optional) Tensorflow Beispiel

# %% [markdown]
# ### Praktische Aufgabe - Nonlinear Climate Control
#
# Im Aufgabenteil zur Regression mit neuronalen Netzen haben Sie bereits mit Daten eines Kühlsystems gearbeitet, die an dieser Stelle nochmals aufgegriffen werden.
# Der Verlauf der Daten ist im folgenden nochmals dargestellt.

# %%
import matplotlib.pyplot as plt
points_climate = dict(x=[25.0, 27.5, 30.0, 32.5, 35, 37.5, 40.0], y=[0.0, 2.0, 10.0, 23.7, 43, 68.7, 100.0])
plt.figure()
plt.scatter(points_climate['x'], points_climate['y'])
plt.xlabel('Temperatur in °C')
plt.ylabel('Optimale Arbeitslast in %')
plt.show()

# %%
import numpy as np
mean_train_data = np.mean(points_climate['x'])
mean_train_labels = np.mean(points_climate['y'])
std_train_data = np.std(points_climate['x'])
std_train_labels = np.std(points_climate['y'])
train_data = np.array([(x-mean_train_data) / std_train_data for x in points_climate['x']], dtype = 'float64').reshape((7,1))
train_labels = np.array([(x-mean_train_labels) / std_train_labels for x in points_climate['y']], dtype = 'float64').reshape((7,1))
print(train_data)
print(train_labels)
# Out:
# [[-1.5]
#  [-1. ]
#  [-0.5]
#  [ 0. ]
#  [ 0.5]
#  [ 1. ]
#  [ 1.5]]
# [[-1.01480496]
#  [-0.95737865]
#  [-0.7276734 ]
#  [-0.33430317]
#  [ 0.21986073]
#  [ 0.95778884]
#  [ 1.85651061]]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Aufgabe 4.3.1:</b> Implementieren Sie ein approximierendes Neuronales Netz mittels Keras. Das Netz soll die optimale Arbeitslast anhand der Temperatur vorhersagen. Speichern Sie das trainierte Modell in einer Variablen mit dem Namen <code>climate_model</code>.
#
# Hinweise:
# * Verwenden Sie die normierten Daten.
# * Verwenden Sie <code>losses.MeanSquaredError</code> als Verlustfunktion.
# * Passen Sie den Aufruf von <code>compile</code> an, sodass <code>metrics=[metrics.MeanSquaredError()]</code> übergeben wird.
# * Verwenden Sie <code>RMSprop</code> mit einer Lernrate von 0.0001.
# * Trainieren Sie 2000 Epochen mit einer Batch Size von 2.
# * Das Neuronale Netz besitzt eine verdeckte Schicht mit 2 Neuronen.
#
# </div>

# %%
# from tensorflow.keras import metrics,Input
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Activation
# from tensorflow.keras import optimizers, losses
# tf.config.run_functions_eagerly(True)

# STUDENT CODE HERE
model_climate = Sequential()

model_climate.add(Input(shape=(1,)))
model_climate.add(Dense(4,activation='relu'))
model_climate.add(Dense(1))

# Show optimizer
rmsprop = optimizers.RMSprop(learning_rate=0.0005, rho=0.9)

# Compile
model_climate.compile(loss="mean_squared_error",
              optimizer=rmsprop,
              metrics=['mean_squared_error'])
# Train


history=model_climate.fit(x=train_data, y=train_labels, batch_size = 2,
          epochs=1000)
# STUDENT CODE until HERE
# Out:
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7571 - mean_squared_error: 0.7571
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7484 - mean_squared_error: 0.7484
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7416 - mean_squared_error: 0.7416
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7357 - mean_squared_error: 0.7357
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7316 - mean_squared_error: 0.7316
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7259 - mean_squared_error: 0.7259
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7223 - mean_squared_error: 0.7223
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7193 - mean_squared_error: 0.7193
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7161 - mean_squared_error: 0.7161
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7116 - mean_squared_error: 0.7116
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7086 - mean_squared_error: 0.7086
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7062 - mean_squared_error: 0.7062
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7033 - mean_squared_error: 0.7033
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7000 - mean_squared_error: 0.7000
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6972 - mean_squared_error: 0.6972
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6944 - mean_squared_error: 0.6944
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6912 - mean_squared_error: 0.6912
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6887 - mean_squared_error: 0.6887
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6863 - mean_squared_error: 0.6863
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6838 - mean_squared_error: 0.6838
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6812 - mean_squared_error: 0.6812
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6778 - mean_squared_error: 0.6778
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6763 - mean_squared_error: 0.6763
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6746 - mean_squared_error: 0.6746
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6727 - mean_squared_error: 0.6727
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6700 - mean_squared_error: 0.6700
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6681 - mean_squared_error: 0.6681
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6661 - mean_squared_error: 0.6661
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6647 - mean_squared_error: 0.6647
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6631 - mean_squared_error: 0.6631
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6611 - mean_squared_error: 0.6611
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6595 - mean_squared_error: 0.6595
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6580 - mean_squared_error: 0.6580
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6557 - mean_squared_error: 0.6557
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6538 - mean_squared_error: 0.6538
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6526 - mean_squared_error: 0.6526
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6507 - mean_squared_error: 0.6507
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6495 - mean_squared_error: 0.6495
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6481 - mean_squared_error: 0.6481
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6468 - mean_squared_error: 0.6468
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6459 - mean_squared_error: 0.6459
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6439 - mean_squared_error: 0.6439
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6432 - mean_squared_error: 0.6432
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6417 - mean_squared_error: 0.6417
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6408 - mean_squared_error: 0.6408
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6405 - mean_squared_error: 0.6405
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6388 - mean_squared_error: 0.6388
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6387 - mean_squared_error: 0.6387
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6369 - mean_squared_error: 0.6369
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6366 - mean_squared_error: 0.6366
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6361 - mean_squared_error: 0.6361
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6352 - mean_squared_error: 0.6352
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6347 - mean_squared_error: 0.6347
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6336 - mean_squared_error: 0.6336
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6322 - mean_squared_error: 0.6322
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6320 - mean_squared_error: 0.6320
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6313 - mean_squared_error: 0.6313
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5900 - mean_squared_error: 0.5900
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5889 - mean_squared_error: 0.5889
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5876 - mean_squared_error: 0.5876
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5870 - mean_squared_error: 0.5870
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5858 - mean_squared_error: 0.5858
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5847 - mean_squared_error: 0.5847
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5838 - mean_squared_error: 0.5838
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5826 - mean_squared_error: 0.5826
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5820 - mean_squared_error: 0.5820
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5809 - mean_squared_error: 0.5809
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5803 - mean_squared_error: 0.5803
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5791 - mean_squared_error: 0.5791
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5783 - mean_squared_error: 0.5783
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5777 - mean_squared_error: 0.5777
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5766 - mean_squared_error: 0.5766
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5758 - mean_squared_error: 0.5758
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5749 - mean_squared_error: 0.5749
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5741 - mean_squared_error: 0.5741
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5727 - mean_squared_error: 0.5727
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5719 - mean_squared_error: 0.5719
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5709 - mean_squared_error: 0.5709
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5701 - mean_squared_error: 0.5701
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5689 - mean_squared_error: 0.5689
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5684 - mean_squared_error: 0.5684
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5673 - mean_squared_error: 0.5673
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5669 - mean_squared_error: 0.5669
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5657 - mean_squared_error: 0.5657
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5649 - mean_squared_error: 0.5649
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5641 - mean_squared_error: 0.5641
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5632 - mean_squared_error: 0.5632
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5622 - mean_squared_error: 0.5622
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5611 - mean_squared_error: 0.5611
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5605 - mean_squared_error: 0.5605
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5598 - mean_squared_error: 0.5598
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5589 - mean_squared_error: 0.5589
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5580 - mean_squared_error: 0.5580
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5573 - mean_squared_error: 0.5573
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5564 - mean_squared_error: 0.5564
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5555 - mean_squared_error: 0.5555
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5548 - mean_squared_error: 0.5548
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5536 - mean_squared_error: 0.5536
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5533 - mean_squared_error: 0.5533
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5522 - mean_squared_error: 0.5522
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5511 - mean_squared_error: 0.5511
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5504 - mean_squared_error: 0.5504
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5493 - mean_squared_error: 0.5493
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5482 - mean_squared_error: 0.5482
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5479 - mean_squared_error: 0.5479
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5470 - mean_squared_error: 0.5470
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5461 - mean_squared_error: 0.5461
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5455 - mean_squared_error: 0.5455
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5448 - mean_squared_error: 0.5448
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5438 - mean_squared_error: 0.5438
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5430 - mean_squared_error: 0.5430
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5427 - mean_squared_error: 0.5427
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5414 - mean_squared_error: 0.5414
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5406 - mean_squared_error: 0.5406
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5397 - mean_squared_error: 0.5397
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5386 - mean_squared_error: 0.5386
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5379 - mean_squared_error: 0.5379
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5367 - mean_squared_error: 0.5367
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5355 - mean_squared_error: 0.5355
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5345 - mean_squared_error: 0.5345
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5337 - mean_squared_error: 0.5337
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5325 - mean_squared_error: 0.5325
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5323 - mean_squared_error: 0.5323
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5312 - mean_squared_error: 0.5312
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5305 - mean_squared_error: 0.5305
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5296 - mean_squared_error: 0.5296
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5288 - mean_squared_error: 0.5288
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5280 - mean_squared_error: 0.5280
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5271 - mean_squared_error: 0.5271
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5266 - mean_squared_error: 0.5266
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5254 - mean_squared_error: 0.5254
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5248 - mean_squared_error: 0.5248
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5238 - mean_squared_error: 0.5238
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5232 - mean_squared_error: 0.5232
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5223 - mean_squared_error: 0.5223
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5215 - mean_squared_error: 0.5215
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5207 - mean_squared_error: 0.5207
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5197 - mean_squared_error: 0.5197
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5193 - mean_squared_error: 0.5193
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5183 - mean_squared_error: 0.5183
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5176 - mean_squared_error: 0.5176
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5171 - mean_squared_error: 0.5171
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5158 - mean_squared_error: 0.5158
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5149 - mean_squared_error: 0.5149
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5143 - mean_squared_error: 0.5143
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5140 - mean_squared_error: 0.5140
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5129 - mean_squared_error: 0.5129
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5121 - mean_squared_error: 0.5121
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5116 - mean_squared_error: 0.5116
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5103 - mean_squared_error: 0.5103
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5101 - mean_squared_error: 0.5101
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5088 - mean_squared_error: 0.5088
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5081 - mean_squared_error: 0.5081
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5076 - mean_squared_error: 0.5076
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5066 - mean_squared_error: 0.5066
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5061 - mean_squared_error: 0.5061
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5052 - mean_squared_error: 0.5052
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5046 - mean_squared_error: 0.5046
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5038 - mean_squared_error: 0.5038
# Epoch 219/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5029 - mean_squared_error: 0.5029
# Epoch 220/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5023 - mean_squared_error: 0.5023
# Epoch 221/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5014 - mean_squared_error: 0.5014
# Epoch 222/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5007 - mean_squared_error: 0.5007
# Epoch 223/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4998 - mean_squared_error: 0.4998
# Epoch 224/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4992 - mean_squared_error: 0.4992
# Epoch 225/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4987 - mean_squared_error: 0.4987
# Epoch 226/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4977 - mean_squared_error: 0.4977
# Epoch 227/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4969 - mean_squared_error: 0.4969
# Epoch 228/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4961 - mean_squared_error: 0.4961
# Epoch 229/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4954 - mean_squared_error: 0.4954
# Epoch 230/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4945 - mean_squared_error: 0.4945
# Epoch 231/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4937 - mean_squared_error: 0.4937
# Epoch 232/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4932 - mean_squared_error: 0.4932
# Epoch 233/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3759 - mean_squared_error: 0.3759
# Epoch 409/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3757 - mean_squared_error: 0.3757
# Epoch 410/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3754 - mean_squared_error: 0.3754
# Epoch 411/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3747 - mean_squared_error: 0.3747
# Epoch 412/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3741 - mean_squared_error: 0.3741
# Epoch 413/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3735 - mean_squared_error: 0.3735
# Epoch 414/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3729 - mean_squared_error: 0.3729
# Epoch 415/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3725 - mean_squared_error: 0.3725
# Epoch 416/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3716 - mean_squared_error: 0.3716
# Epoch 417/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3713 - mean_squared_error: 0.3713
# Epoch 418/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3708 - mean_squared_error: 0.3708
# Epoch 419/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3700 - mean_squared_error: 0.3700
# Epoch 420/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3696 - mean_squared_error: 0.3696
# Epoch 421/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3691 - mean_squared_error: 0.3691
# Epoch 422/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3686 - mean_squared_error: 0.3686
# Epoch 423/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3679 - mean_squared_error: 0.3679
# Epoch 424/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3671 - mean_squared_error: 0.3671
# Epoch 425/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3667 - mean_squared_error: 0.3667
# Epoch 426/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3662 - mean_squared_error: 0.3662
# Epoch 427/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3656 - mean_squared_error: 0.3656
# Epoch 428/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3650 - mean_squared_error: 0.3650
# Epoch 429/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3648 - mean_squared_error: 0.3648
# Epoch 430/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3643 - mean_squared_error: 0.3643
# Epoch 431/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3637 - mean_squared_error: 0.3637
# Epoch 432/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3633 - mean_squared_error: 0.3633
# Epoch 433/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3627 - mean_squared_error: 0.3627
# Epoch 434/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3619 - mean_squared_error: 0.3619
# Epoch 435/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3617 - mean_squared_error: 0.3617
# Epoch 436/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3610 - mean_squared_error: 0.3610
# Epoch 437/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3606 - mean_squared_error: 0.3606
# Epoch 438/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3601 - mean_squared_error: 0.3601
# Epoch 439/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3598 - mean_squared_error: 0.3598
# Epoch 440/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3591 - mean_squared_error: 0.3591
# Epoch 441/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3584 - mean_squared_error: 0.3584
# Epoch 442/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3580 - mean_squared_error: 0.3580
# Epoch 443/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3574 - mean_squared_error: 0.3574
# Epoch 444/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3569 - mean_squared_error: 0.3569
# Epoch 445/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3565 - mean_squared_error: 0.3565
# Epoch 446/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3559 - mean_squared_error: 0.3559
# Epoch 447/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3553 - mean_squared_error: 0.3553
# Epoch 448/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3547 - mean_squared_error: 0.3547
# Epoch 449/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3543 - mean_squared_error: 0.3543
# Epoch 450/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3536 - mean_squared_error: 0.3536
# Epoch 451/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3531 - mean_squared_error: 0.3531
# Epoch 452/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3526 - mean_squared_error: 0.3526
# Epoch 453/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3522 - mean_squared_error: 0.3522
# Epoch 454/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3512 - mean_squared_error: 0.3512
# Epoch 455/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3508 - mean_squared_error: 0.3508
# Epoch 456/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3506 - mean_squared_error: 0.3506
# Epoch 457/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3501 - mean_squared_error: 0.3501
# Epoch 458/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3497 - mean_squared_error: 0.3497
# Epoch 459/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3488 - mean_squared_error: 0.3488
# Epoch 460/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3485 - mean_squared_error: 0.3485
# Epoch 461/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3477 - mean_squared_error: 0.3477
# Epoch 462/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3473 - mean_squared_error: 0.3473
# Epoch 463/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469 - mean_squared_error: 0.3469
# Epoch 464/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3464 - mean_squared_error: 0.3464
# Epoch 465/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3461 - mean_squared_error: 0.3461
# Epoch 466/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3454 - mean_squared_error: 0.3454
# Epoch 467/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3449 - mean_squared_error: 0.3449
# Epoch 468/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3445 - mean_squared_error: 0.3445
# Epoch 469/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3440 - mean_squared_error: 0.3440
# Epoch 470/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3432 - mean_squared_error: 0.3432
# Epoch 471/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3427 - mean_squared_error: 0.3427
# Epoch 472/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3423 - mean_squared_error: 0.3423
# Epoch 473/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3420 - mean_squared_error: 0.3420
# Epoch 474/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3413 - mean_squared_error: 0.3413
# Epoch 475/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3409 - mean_squared_error: 0.3409
# Epoch 476/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3404 - mean_squared_error: 0.3404
# Epoch 477/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3398 - mean_squared_error: 0.3398
# Epoch 478/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3394 - mean_squared_error: 0.3394
# Epoch 479/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3388 - mean_squared_error: 0.3388
# Epoch 480/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3384 - mean_squared_error: 0.3384
# Epoch 481/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3376 - mean_squared_error: 0.3376
# Epoch 482/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3372 - mean_squared_error: 0.3372
# Epoch 483/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3364 - mean_squared_error: 0.3364
# Epoch 484/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3357 - mean_squared_error: 0.3357
# Epoch 485/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3352 - mean_squared_error: 0.3352
# Epoch 486/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3342 - mean_squared_error: 0.3342
# Epoch 487/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3337 - mean_squared_error: 0.3337
# Epoch 488/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3332 - mean_squared_error: 0.3332
# Epoch 489/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3326 - mean_squared_error: 0.3326
# Epoch 490/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3319 - mean_squared_error: 0.3319
# Epoch 491/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3313 - mean_squared_error: 0.3313
# Epoch 492/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3304 - mean_squared_error: 0.3304
# Epoch 493/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3299 - mean_squared_error: 0.3299
# Epoch 494/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3292 - mean_squared_error: 0.3292
# Epoch 495/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3287 - mean_squared_error: 0.3287
# Epoch 496/1000
# ...
# Epoch 839/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1667 - mean_squared_error: 0.1667
# Epoch 840/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1664 - mean_squared_error: 0.1664
# Epoch 841/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1659 - mean_squared_error: 0.1659
# Epoch 842/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1658 - mean_squared_error: 0.1658
# Epoch 843/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1654 - mean_squared_error: 0.1654
# Epoch 844/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1650 - mean_squared_error: 0.1650
# Epoch 845/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1647 - mean_squared_error: 0.1647
# Epoch 846/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1644 - mean_squared_error: 0.1644
# Epoch 847/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1641 - mean_squared_error: 0.1641
# Epoch 848/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1639 - mean_squared_error: 0.1639
# Epoch 849/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1636 - mean_squared_error: 0.1636
# Epoch 850/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1633 - mean_squared_error: 0.1633
# Epoch 851/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1630 - mean_squared_error: 0.1630
# Epoch 852/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1628 - mean_squared_error: 0.1628
# Epoch 853/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1624 - mean_squared_error: 0.1624
# Epoch 854/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1620 - mean_squared_error: 0.1620
# Epoch 855/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1617 - mean_squared_error: 0.1617
# Epoch 856/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1614 - mean_squared_error: 0.1614
# Epoch 857/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1610 - mean_squared_error: 0.1610
# Epoch 858/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1607 - mean_squared_error: 0.1607
# Epoch 859/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1604 - mean_squared_error: 0.1604
# Epoch 860/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1602 - mean_squared_error: 0.1602
# Epoch 861/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1599 - mean_squared_error: 0.1599
# Epoch 862/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1595 - mean_squared_error: 0.1595
# Epoch 863/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1593 - mean_squared_error: 0.1593
# Epoch 864/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1590 - mean_squared_error: 0.1590
# Epoch 865/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1587 - mean_squared_error: 0.1587
# Epoch 866/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1582 - mean_squared_error: 0.1582
# Epoch 867/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1409 - mean_squared_error: 0.1409
# Epoch 926/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1405 - mean_squared_error: 0.1405
# Epoch 927/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1402 - mean_squared_error: 0.1402
# Epoch 928/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1400 - mean_squared_error: 0.1400
# Epoch 929/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1397 - mean_squared_error: 0.1397
# Epoch 930/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1395 - mean_squared_error: 0.1395
# Epoch 931/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1392 - mean_squared_error: 0.1392
# Epoch 932/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1389 - mean_squared_error: 0.1389
# Epoch 933/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1387 - mean_squared_error: 0.1387
# Epoch 934/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1384 - mean_squared_error: 0.1384
# Epoch 935/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1381 - mean_squared_error: 0.1381
# Epoch 936/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1378 - mean_squared_error: 0.1378
# Epoch 937/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1376 - mean_squared_error: 0.1376
# Epoch 938/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1372 - mean_squared_error: 0.1372
# Epoch 939/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1370 - mean_squared_error: 0.1370
# Epoch 940/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1368 - mean_squared_error: 0.1368
# Epoch 941/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1365 - mean_squared_error: 0.1365
# Epoch 942/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1363 - mean_squared_error: 0.1363
# Epoch 943/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1360 - mean_squared_error: 0.1360
# Epoch 944/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1358 - mean_squared_error: 0.1358
# Epoch 945/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1356 - mean_squared_error: 0.1356
# Epoch 946/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1352 - mean_squared_error: 0.1352
# Epoch 947/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1350 - mean_squared_error: 0.1350
# Epoch 948/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1348 - mean_squared_error: 0.1348
# Epoch 949/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1345 - mean_squared_error: 0.1345
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1342 - mean_squared_error: 0.1342
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1340 - mean_squared_error: 0.1340
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1337 - mean_squared_error: 0.1337
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1335 - mean_squared_error: 0.1335
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1331 - mean_squared_error: 0.1331
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1328 - mean_squared_error: 0.1328
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1326 - mean_squared_error: 0.1326
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1324 - mean_squared_error: 0.1324
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1322 - mean_squared_error: 0.1322
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1319 - mean_squared_error: 0.1319
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1315 - mean_squared_error: 0.1315
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1314 - mean_squared_error: 0.1314
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1312 - mean_squared_error: 0.1312
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1310 - mean_squared_error: 0.1310
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1307 - mean_squared_error: 0.1307
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1305 - mean_squared_error: 0.1305
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1302 - mean_squared_error: 0.1302
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1300 - mean_squared_error: 0.1300
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1298 - mean_squared_error: 0.1298
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1295 - mean_squared_error: 0.1295
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1292 - mean_squared_error: 0.1292
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1289 - mean_squared_error: 0.1289
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1287 - mean_squared_error: 0.1287
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1285 - mean_squared_error: 0.1285
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1282 - mean_squared_error: 0.1282
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1279 - mean_squared_error: 0.1279
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1275 - mean_squared_error: 0.1275
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1274 - mean_squared_error: 0.1274
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1273 - mean_squared_error: 0.1273
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1271 - mean_squared_error: 0.1271
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1269 - mean_squared_error: 0.1269
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1265 - mean_squared_error: 0.1265
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1263 - mean_squared_error: 0.1263
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1261 - mean_squared_error: 0.1261
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1259 - mean_squared_error: 0.1259
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1257 - mean_squared_error: 0.1257
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1255 - mean_squared_error: 0.1255
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1252 - mean_squared_error: 0.1252
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1250 - mean_squared_error: 0.1250
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1247 - mean_squared_error: 0.1247
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1245 - mean_squared_error: 0.1245
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1242 - mean_squared_error: 0.1242
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1239 - mean_squared_error: 0.1239
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1238 - mean_squared_error: 0.1238
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1235 - mean_squared_error: 0.1235
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1233 - mean_squared_error: 0.1233
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1229 - mean_squared_error: 0.1229
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1227 - mean_squared_error: 0.1227
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1225 - mean_squared_error: 0.1225
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1223 - mean_squared_error: 0.1223
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1221 - mean_squared_error: 0.1221

# %%
from tensorflow.data import Dataset
# from tensorflow.keras import metrics
x_values = [x for x in range(int(min(points_climate['x'])), int(max(points_climate['x']))+1)]
x_values_norm = np.array([ (x - mean_train_data) / std_train_data for x in x_values], dtype = 'float64').reshape((16,1))
# test_data = Dataset.from_tensor_slices(x_values).batch(2)
y_pred = model_climate.predict(x_values_norm)
y_pred_denorm = [(x*std_train_labels)+mean_train_labels for x in y_pred]

plt.figure()
plt.plot(points_climate['x'], points_climate['y'], marker='o', linestyle='None', label='Train data')
plt.plot(x_values, y_pred_denorm, label='Ausgabe Model', marker='o', linestyle='dashed')
plt.legend()
plt.show()

plt.figure()
plt.plot(np.arange(1,1001,1),history.history['loss'])
plt.title("Training loss")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Text(0.5, 1.0, 'Training loss')

# %% [markdown]
# #### Über Tensorflow
#
# TensorFlow ist eine Open-Source-Softwarebibliothek für die Datenflussprogrammierung und kann für eine Reihe von Aufgaben eingesetzt werden. Sie ist eine symbolische mathematische Bibliothek, die für maschinelle Lernanwendungen wie neuronale Netze verwendet wird.
#
#
# <figure>
# <img  src="./images/tensor-flow.png" width="100" align="center"/>
# </figure>
#
#
# #### Funktionsweise
# Das Definieren eines Modells in Tensorflow ist etwas umständlicher als in Keras, erlaubt es uns aber, genauere Einstellungen vorzunehmen. Im ersten Schritt definieren wir die Struktur unsere Daten mit sogenannte Placeholder mit der `tf.placeholder()` Funktion. Die Variable `phX` steht dabei für den Eingang und `phY` für den Ausgang. Beim Initialisieren dieser Placeholder können wir sowohl den Datentyp, in unserem Fall float32, als auch die Form der Daten (engl. shape) festlegen. In diesem Beispiel ist unser Eingang zweidimensional und unser Ausgang eindimensional, weshalb wir hier für `phX` 2 und `phY` 1 wählen. Das `None` an erster Stelle der Shape bedeutet dabei, dass die erste Dimension, die der Batch-Größe entspricht, eine beliebige Größe haben kann.
#
# Als nächstes initialisieren wir die Gewichte und Bias unseres Netzes mit zufälligen Startwerten. Beachten Sie, dass `w1` und `w2` bzw. `b1` und `b2` Matrizen sind, also mehrere Gewichte/Bias für einen Layer in einer Variablen vereinen.
#
# Diese initialisierten Gewichte und Bias können wir dann an die Feed-Forward Funktion `forward()` übergeben, in der wir den mathematische Zusammenhang zwischen Ein- und Ausgang in unserem Tensorflow-Netz definieren. In diesem Fall definieren wir ein Modell mit zwei Schichten. Der Ausgang beider Schichten ergibt sich jeweils durch Matrixmultiplikation (`tf.matmul()`) von Schichteingang und Gewichten der jeweiligen Schicht und anschließender Addition mit den Bias. In der ersten Schicht wird außerdem wieder die Sigmoid Funktion auf den Ausgang angewendet, während für die Ausgangsschicht die Softmax Funktion verwendet wird (hier direkt beim Berechnen der Kosten `cost`).
#
# Ähnlich wie beim Training mit Keras müssen wir auch bei Tensorflow Lernrate, die Anzahl an Epochen, die zu minimierende Kostenfunktion sowie das Optimierungsverfahren spezifizieren. Das Training kann anschließend durch das Erstellen einer neuen Session begonnen werden. In der anschließenden For-Loop führen wir die Session mit dem `run()` Befehl so häufig aus, wie durch die `nb_epochs` Variable spezifiziert, sodass wir das Training für die gewünschte Epochenanzahl durchführen.

# %%
# Import tensorflow
import tensorflow as tf

# Feedforward function
def forward(x, w1, b1, w2, b2):
    
    Z = tf.nn.relu(tf.matmul(x,w1) + b1)
    Z2 = tf.matmul(Z,w2) + b2
    
    return Z2
    
def init_weights(shape):
    return tf.Variable(tf.random_normal(shape, stddev = 0.1))


# Define PlaceHolder for input x_train and output y_train
try:
    phX = tf.placeholder(tf.float32, [None, 2])
    phY = tf.placeholder(tf.float32, [None, 1])
except AttributeError:
    import tensorflow.compat.v1 as tf
    tf.disable_v2_behavior() 
    phX = tf.placeholder(tf.float32, [None, 2])
    phY = tf.placeholder(tf.float32, [None, 1])
    
# Init weights
w1 = init_weights([2, 3])
b1 = init_weights([3])
w2 = init_weights([3, 1])
b2 = init_weights([1])

y_pred = forward(phX, w1, b1, w2, b2)

lr = 0.1
nb_epochs = 201

# Init cost function
cost = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=y_pred, labels=phY))

# Init optimizer
train = tf.train.AdamOptimizer(lr).minimize(cost)

# Create session and init variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# Start training
for i in range(nb_epochs):
    sess.run(train, feed_dict={phX: x_train, phY: y_train})
    c = sess.run(cost, feed_dict={phX: x_train, phY: y_train})
    if i%50 == 0:
        print("Iteration {: >8}  |  Cost: {}".format(i,c))
# Out:
# WARNING:tensorflow:From C:\Users\anderlfr\AppData\Local\Temp\ipykernel_25544\1026511161.py:22: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\Users\anderlfr\gitlab_projects\AMALEA\AMALEA_3_13\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\anderlfr\AppData\Local\Temp\ipykernel_25544\1026511161.py:43: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Iteration        0  |  Cost: 0.6951223611831665
# Iteration       50  |  Cost: 0.4780062735080719
# Iteration      100  |  Cost: 0.4775124490261078
# Iteration      150  |  Cost: 0.4774599075317383
# Iteration      200  |  Cost: 0.4776589274406433

# %% [markdown]
# #### Über Pytorch
# PyTorch ist eine Open-Source-Bibliothek für maschinelles Lernen, die auf der Torch-Bibliothek basiert. Sie wird für Anwendungen wie Computer Vision und Verarbeitung natürlicher Sprache verwendet und hauptsächlich von Facebooks AI Research Lab entwickelt. Auch Pytorch ist ein kostenloses Opensource Projekt. Unterscheidungsmerkmal zu den vorherigen Bibliotheken ist die durchgängige Anwendung der Objektorientierung.
# <figure>
# <img  src="./images/pytorch.png" width="100" align="center"/>
# </figure>
#
# #### Funktionsweise
# Zunächst definieren wir eine neue Klasse `Net` die unser neuronales Netz repräsentiert. In der Init-Methode (Konstruktor) dieser Klasse initialisieren wir die beiden Schichten unseres Netzes. Anders als im vorherigen Tensorflow Beispiel müssen wir dabei die Shapes der beiden Schichten explizit angeben. In diesem Beispiel verwenden wir die [Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html) Klasse, die eine lineare Transformation der Form  $y=xA^T+b$ durchführt. So können wir direkt unsere beiden Schichten `fc1` und `fc2` definieren. Wie auch bei der Tensorflow Implementation benötigen wir eine `forward` Methode, die uns den Ausgang des Netzes berechnet. Wir versehen den Ausgang der ersten Schicht `fc1` erneut mit der ReLU Funktion und geben diesen auf die zweite Schicht `fc2`. Auf den Ausgang dieser zweiten Schicht wenden wir dann die Sigmoid Aktivierungsfunktion an.
#
# Auch anders als bei der Implementation mit Tensorflow ist, dass wir beim Verwenden von Pytorch Torch Tensoren als Eingänge benötigen. Daher konvertieren wir unsere Numpy Trainingsdaten entsprechend.
#
# Auch hier können wir wichtige Einstellungen wie die Festlegung des Optimizers und der Verlustmetrik vornehmen, ehe wir mit dem Training beginnen.
#
# Während des Trainings innerhalb der For-Loop erfolgt jede Aktualisierung des Modells nach dem gleichen Muster:
#
# - Löschen des letzten Fehlergradienten: `optimizer.zero_grad()`
# - Ein Vorwärtsdurchlauf (feedforward) der Eingabe durch das Modell: `net(input)`
# - Berechnung des Verlusts für die Modellausgabe: `criterion(output, target)`
# - Backpropagation des Fehlers durch das Modell: `loss.backward()`
# - Aktualisieren des Modells, um den Verlust zu reduzieren: `optimizer.step()`
#
# Anders als bei der Tensorflow Implementation verschachteln wir dabei zwei For-Loops ineinander. Die innere Schleife füttert das Netz dabei jeweils mit einem einzelnen Eintrag aus unserem Datensatz (`input` und `target`), während die äußere Schleife die aktuelle Epoche steuert (`idx`).

# %% [markdown]
# ### (Optional) Pytorch Beispiel

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 3, True)
        self.fc2 = nn.Linear(3, 1, True)

    def forward(self, x:float) -> float:
        x = F.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x

net = Net()

inputs = torch.from_numpy(x_train).type(torch.FloatTensor)
targets = torch.from_numpy(y_train).type(torch.FloatTensor)

criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters(), lr=0.01)

print("Training loop:")
for idx in range(0, 201):
    for input, target in zip(inputs, targets):
        optimizer.zero_grad()   # zero the gradient buffers
        output = net(input)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()    # Does the update
    if idx % 50 == 0:
        print("Epoch: {: >8}  |  Loss: {}".format(idx, loss.data.numpy()))
# Out:
# Training loop:
# Epoch:        0  |  Loss: 0.7585883140563965
# Epoch:       50  |  Loss: 0.6364494562149048
# Epoch:      100  |  Loss: 0.6525589227676392
# Epoch:      150  |  Loss: 0.6646940112113953
# Epoch:      200  |  Loss: 0.6729295253753662
